# %%
energy_df
# Out:
#                   country  year  total_consumption  \
# 0               Australia  2015           5318.155
# 1              Bangladesh  2015           2788.196
# 2                  Brazil  2015          10456.885
# 3                  Canada  2015          11215.963
# 4                   China  2015          76094.257
# ..                    ...   ...                ...
# 235                Turkey  2022           6330.736
# 236  United Arab Emirates  2022           4662.861
# 237        United Kingdom  2022           6455.663
# 238         United States  2022          58023.664
# 239               Vietnam  2022           4852.226
#
#      energy_consumption_per_capita
# 0                         0.000223
# 1                         0.000018
# 2                         0.000051
# 3                         0.000314
# 4                         0.000055
# ..                             ...
# 235                       0.000074
# 236                       0.000494
# 237                       0.000096
# 238                       0.000172
# 239                       0.000049
#
# [240 rows x 4 columns]

# %%
gdp_df
# Out:
#                   country           gdp  gdp_per_capita  year
# 0               Australia  1.140000e+12    47858.459864  2015
# 1              Bangladesh  5.520000e+11     3497.433948  2015
# 2                  Brazil  3.020000e+12    14718.194722  2015
# 3                  Canada  1.570000e+12    43938.059091  2015
# 4                   China  1.830000e+13    13130.370278  2015
# ..                    ...           ...             ...   ...
# 235                Turkey  2.390000e+12    28005.215016  2022
# 236  United Arab Emirates  7.800000e+11    82617.159076  2022
# 237        United Kingdom  2.620000e+12    38809.676989  2022
# 238         United States  1.950000e+13    57642.875345  2022
# 239               Vietnam  8.340000e+11     8494.008607  2022
#
# [240 rows x 4 columns]

# %%
happiness_df_filtered["year"].unique()
happiness_df_filtered.head()
# Out:
#          country  happiness_score  year
# 0         Canada            7.427  2015
# 1    Netherlands            7.378  2015
# 2      Australia            7.284  2015
# 3         Mexico            7.187  2015
# 4  United States            7.119  2015

# %%
def calculate_aqi(concentration, breakpoints):
    for i in range(len(breakpoints)):
        if breakpoints[i][0] <= concentration <= breakpoints[i][1]:
            c_low, c_high = breakpoints[i][0], breakpoints[i][1]
            aqi_low, aqi_high = breakpoints[i][2], breakpoints[i][3]
            aqi = ((aqi_high - aqi_low) / (c_high - c_low)) * (concentration - c_low) + aqi_low
            return aqi
    return None

def aqi_category(aqi, breakpoints):
    for i in range(len(breakpoints)):
        if breakpoints[i][2] <= aqi <= breakpoints[i][3]:
            return breakpoints[i][4]
    return None

pm25_breakpoints = [
    (0, 9, 0, 50, "GOOD"), (9.1, 35.4, 51, 100, "MODERATE"), (35.5, 55.4, 101, 150, "UNHEALTHY FOR SENSITIVE"),
    (55.5, 125.4, 151, 200, "UNHEALTHY"), (125.5, 225.4, 201, 300, "VERY UNHEALTHY"), (225.5, 325.4, 301, 500, "HAZARDOUS"), (325.5, 99999.9, 501, 999, "VERY HAZARDOUS")
]

air_quality_df['aqi_pm25_concentration'] = air_quality_df['average_pm25_concentration'].apply(lambda x: calculate_aqi(x, pm25_breakpoints))
air_quality_df['aqi_pm25_category'] = air_quality_df['aqi_pm25_concentration'].apply(lambda x: aqi_category(x, pm25_breakpoints))

# %%
air_quality_df.head()
# Out:
#       country  year  average_pm25_concentration  aqi_pm25_concentration  \
# 0   Australia  2015                    4.086677               22.703763
# 1  Bangladesh  2015                   78.139111              166.870049
# 2      Brazil  2015                    2.971552               16.508621
# 3      Canada  2015                    6.710247               37.279149
# 4       China  2015                   49.557086              135.612924
#
#          aqi_pm25_category
# 0                     GOOD
# 1                UNHEALTHY
# 2                     GOOD
# 3                     GOOD
# 4  UNHEALTHY FOR SENSITIVE

# %%
gdp_df.head()
# Out:
#       country           gdp  gdp_per_capita  year
# 0   Australia  1.140000e+12    47858.459864  2015
# 1  Bangladesh  5.520000e+11     3497.433948  2015
# 2      Brazil  3.020000e+12    14718.194722  2015
# 3      Canada  1.570000e+12    43938.059091  2015
# 4       China  1.830000e+13    13130.370278  2015

# %%
unemployed_rate_df.head()
# Out:
#                 country  unemployed_rate  year
# 0  United Arab Emirates            1.792  2015
# 1             Australia            6.055  2015
# 2            Bangladesh            4.382  2015
# 3                Brazil            8.538  2015
# 4                Canada            6.945  2015

# %%
cpi_df.head()
# Out:
#                 country       cpi  year
# 0  United Arab Emirates  4.069966  2015
# 1             Australia  1.508367  2015
# 2            Bangladesh  6.194280  2015
# 3                Brazil  9.029901  2015
# 4                Canada  1.125241  2015

# %%
hdi_df.head()
# Out:
#                 country    hdi  year
# 0  United Arab Emirates  0.860  2015
# 1             Australia  0.933  2015
# 2            Bangladesh  0.604  2015
# 3                Brazil  0.752  2015
# 4                Canada  0.927  2015

# %%
tasks_columns = ["country", "year", "total_consumption", "energy_consumption_per_capita", "happiness_score", "average_pm25_concentration", "aqi_pm25_concentration", "aqi_pm25_category", "gdp", "gdp_per_capita", "unemployed_rate", "cpi", "hdi"]
tasks_df = pd.merge(gdp_df, happiness_df, on=["country", "year"])
tasks_df = pd.merge(tasks_df, energy_df, on=["country", "year"])
tasks_df = pd.merge(air_quality_df, tasks_df, on=["country", "year"])
tasks_df = pd.merge(unemployed_rate_df, tasks_df, on=["country", "year"])
tasks_df = pd.merge(cpi_df, tasks_df, on=["country", "year"])
tasks_df = pd.merge(hdi_df, tasks_df, on=["country", "year"])
tasks_df = tasks_df[tasks_columns]
tasks_df = tasks_df[(tasks_df != 0).all(axis=1)]

# %%
tasks_df.describe()
# Out:
#               year  total_consumption  energy_consumption_per_capita  \
# count   133.000000         133.000000                     133.000000
# mean   2017.661654       13208.656143                       0.000120
# std       1.886504       19086.289162                       0.000098
# min    2015.000000        2022.000000                       0.000014
# 25%    2016.000000        4652.083000                       0.000054
# 50%    2018.000000        6488.798000                       0.000103
# 75%    2019.000000       10262.278000                       0.000160
# max    2022.000000       90849.856000                       0.000490
#
#        happiness_score  average_pm25_concentration  aqi_pm25_concentration  \
# count       133.000000                  133.000000              131.000000
# mean          6.123479                   17.296227               59.622850
# std           0.912153                   18.646740               38.600692
# min           3.573300                    2.674286               14.857143
# 25%           5.345000                    5.535363               30.727352
# 50%           6.310000                    8.339847               44.885306
# 75%           6.939600                   23.215000               77.421806
# max           7.488000                   90.244225              175.355751
#
#                 gdp  gdp_per_capita  unemployed_rate         cpi         hdi
# count  1.330000e+02      133.000000       133.000000  133.000000  133.000000
# mean   3.895564e+12    29990.250767         6.290233    2.810248    0.833474
# std    5.489587e+12    17843.690594         3.918791    3.114159    0.109957
# min    5.520000e+11     3497.433948         0.597000   -1.931081    0.535000
# 25%    1.150000e+12    14321.971781         3.746000    0.989487    0.757000
# 50%    1.960000e+12    32922.115313         4.830000    1.911401    0.889000
# 75%    3.050000e+12    44228.793134         8.010000    3.520257    0.926000
# max    2.420000e+13    79790.178969        22.058000   16.332464    0.951000

# %%
tasks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133 entries, 1 to 146
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   country                        133 non-null    object
#  1   year                           133 non-null    int64
#  2   total_consumption              133 non-null    float64
#  3   energy_consumption_per_capita  133 non-null    float64
#  4   happiness_score                133 non-null    float64
#  5   average_pm25_concentration     133 non-null    float64
#  6   aqi_pm25_concentration         131 non-null    float64
#  7   aqi_pm25_category              131 non-null    object
#  8   gdp                            133 non-null    float64
#  9   gdp_per_capita                 133 non-null    float64
#  10  unemployed_rate                133 non-null    float64
#  11  cpi                            133 non-null    float64
#  12  hdi                            133 non-null    float64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 14.5+ KB

# %%
tasks_df.isnull().sum()
# Out:
# country                          0
# year                             0
# total_consumption                0
# energy_consumption_per_capita    0
# happiness_score                  0
# average_pm25_concentration       0
# aqi_pm25_concentration           2
# aqi_pm25_category                2
# gdp                              0
# gdp_per_capita                   0
# unemployed_rate                  0
# cpi                              0
# hdi                              0
# dtype: int64

# %%
tasks_df.dropna(inplace=True)

# %%
tasks_df.isnull().sum()
# Out:
# country                          0
# year                             0
# total_consumption                0
# energy_consumption_per_capita    0
# happiness_score                  0
# average_pm25_concentration       0
# aqi_pm25_concentration           0
# aqi_pm25_category                0
# gdp                              0
# gdp_per_capita                   0
# unemployed_rate                  0
# cpi                              0
# hdi                              0
# dtype: int64

# %%
tasks_df
# Out:
#            country  year  total_consumption  energy_consumption_per_capita  \
# 1        Australia  2015           5318.155                       0.000223
# 2       Bangladesh  2015           2788.196                       0.000018
# 3           Brazil  2015          10456.885                       0.000051
# 4           Canada  2015          11215.963                       0.000314
# 5            China  2015          76094.257                       0.000055
# ..             ...   ...                ...                            ...
# 140          Italy  2021           5886.828                       0.000099
# 142   Saudi Arabia  2021           7982.646                       0.000222
# 143       Thailand  2021           4894.876                       0.000068
# 144  United States  2021          56660.668                       0.000168
# 146   Saudi Arabia  2022           2022.000                       0.000056
#
#      happiness_score  average_pm25_concentration  aqi_pm25_concentration  \
# 1              7.284                    4.086677               22.703763
# 2              4.694                   78.139111              166.870049
# 3              6.983                    2.971552               16.508621
# 4              7.427                    6.710247               37.279149
# 5              5.140                   49.557086              135.612924
# ..               ...                         ...                     ...
# 140            6.483                    7.373092               40.961621
# 142            6.494                    3.507692               19.487179
# 143            5.985                   20.668848               72.554127
# 144            6.951                    6.938957               38.549760
# 146            6.523                   14.930769               61.863410
#
#            aqi_pm25_category           gdp  gdp_per_capita  unemployed_rate  \
# 1                       GOOD  1.140000e+12    47858.459864            6.055
# 2                  UNHEALTHY  5.520000e+11     3497.433948            4.382
# 3                       GOOD  3.020000e+12    14718.194722            8.538
# 4                       GOOD  1.570000e+12    43938.059091            6.945
# 5    UNHEALTHY FOR SENSITIVE  1.830000e+13    13130.370278            4.650
# ..                       ...           ...             ...              ...
# 140                     GOOD  2.060000e+12    34773.604255            9.497
# 142                     GOOD  1.680000e+12    46731.056871            6.621
# 143                 MODERATE  1.100000e+12    15362.891611            1.215
# 144                     GOOD  1.910000e+13    56676.956116            5.349
# 146                 MODERATE  1.820000e+12    49987.882058            5.589
#
#           cpi    hdi
# 1    1.508367  0.933
# 2    6.194280  0.604
# 3    9.029901  0.752
# 4    1.125241  0.927
# 5    1.437024  0.741
# ..        ...    ...
# 140  1.873783  0.899
# 142  3.063290  0.867
# 143  1.230395  0.797
# 144  4.697859  0.921
# 146  2.474074  0.875
#
# [131 rows x 13 columns]

# %%
tasks_df[tasks_df["country"] == "China"]
# Out:
#     country  year  total_consumption  energy_consumption_per_capita  \
# 5     China  2015          76094.257                       0.000055
# 29    China  2016          76707.739                       0.000055
# 53    China  2017          79820.423                       0.000057
# 76    China  2018          83777.827                       0.000059
# 99    China  2019          87805.094                       0.000062
# 120   China  2020          90849.856                       0.000064
#
#      happiness_score  average_pm25_concentration  aqi_pm25_concentration  \
# 5             5.1400                   49.557086              135.612924
# 29            5.2450                   45.739159              126.211999
# 53            5.2730                   44.610489              123.432863
# 76            5.2460                   40.153056              112.457274
# 99            5.1910                   38.475538              108.326701
# 120           5.1239                   33.631841               96.705712
#
#            aqi_pm25_category           gdp  gdp_per_capita  unemployed_rate  \
# 5    UNHEALTHY FOR SENSITIVE  1.830000e+13    13130.370278             4.65
# 29   UNHEALTHY FOR SENSITIVE  1.950000e+13    13909.796542             4.56
# 53   UNHEALTHY FOR SENSITIVE  2.090000e+13    14819.794476             4.47
# 76   UNHEALTHY FOR SENSITIVE  2.230000e+13    15736.702359             4.31
# 99   UNHEALTHY FOR SENSITIVE  2.360000e+13    16597.929857             4.56
# 120                 MODERATE  2.420000e+13    16983.292886             5.00
#
#           cpi    hdi
# 5    1.437024  0.741
# 29   2.000002  0.749
# 53   1.593136  0.757
# 76   2.074790  0.766
# 99   2.899234  0.775
# 120  2.419422  0.781

# %%
tasks_df[tasks_df["country"] == "United States"]
# Out:
#            country  year  total_consumption  energy_consumption_per_capita  \
# 23   United States  2015          55432.831                       0.000171
# 47   United States  2016          55601.287                       0.000170
# 69   United States  2017          56009.588                       0.000170
# 92   United States  2018          57955.215                       0.000174
# 116  United States  2019          57651.207                       0.000172
# 133  United States  2020          53855.538                       0.000160
# 144  United States  2021          56660.668                       0.000168
#
#      happiness_score  average_pm25_concentration  aqi_pm25_concentration  \
# 23            7.1190                    7.236025               40.200137
# 47            7.1040                    6.506025               36.144582
# 69            6.9930                    6.878247               38.212483
# 92            6.8860                    7.011235               38.951303
# 116           6.8920                    6.493157               36.073097
# 133           6.9396                    6.744562               37.469787
# 144           6.9510                    6.938957               38.549760
#
#     aqi_pm25_category           gdp  gdp_per_capita  unemployed_rate  \
# 23               GOOD  1.690000e+13    52062.831668            5.280
# 47               GOOD  1.720000e+13    52565.597220            4.869
# 69               GOOD  1.760000e+13    53367.094975            4.355
# 92               GOOD  1.810000e+13    54495.087181            3.896
# 116              GOOD  1.850000e+13    55336.257800            3.669
# 133              GOOD  1.800000e+13    53580.675065            8.055
# 144              GOOD  1.910000e+13    56676.956116            5.349
#
#           cpi    hdi
# 23   0.118627  0.924
# 47   1.261583  0.926
# 69   2.130110  0.928
# 92   2.442583  0.930
# 116  1.812210  0.933
# 133  1.233584  0.923
# 144  4.697859  0.921

# %%
tasks_df[tasks_df["country"] == "Japan"]
# Out:
#     country  year  total_consumption  energy_consumption_per_capita  \
# 84    Japan  2018          13132.519                       0.000104
# 107   Japan  2019          12913.366                       0.000103
#
#      happiness_score  average_pm25_concentration  aqi_pm25_concentration  \
# 84             5.915                   11.471067               55.417577
# 107            5.886                   10.107067               52.876284
#
#     aqi_pm25_category           gdp  gdp_per_capita  unemployed_rate  \
# 84           MODERATE  4.850000e+12    38414.054912            2.467
# 107          MODERATE  4.830000e+12    38396.816069            2.351
#
#           cpi    hdi
# 84   0.989095  0.917
# 107  0.468776  0.918

# %%
tasks_df.to_csv("tasks.csv", index=False)

# %% [markdown]
# ## Dummy

# %%
def scale_series(series):
    return 100 * (series / series.max())

scaled_df = task_three_df.copy()
for column in task_three_df.select_dtypes(include=['float64']).columns:
    scaled_df[f"indexed_{column}"] = scale_series(task_three_df[column])
    
# write csv file
scaled_df.to_csv("task_three_scaled.csv", index=False)

scaled_df.head()
# Out:
#       country  year  total_consumption  happiness_score  \
# 0   Australia  2015           3303.155            7.284
# 1  Bangladesh  2015            773.196            4.694
# 2      Brazil  2015           8441.885            6.983
# 3      Canada  2015           9200.963            7.427
# 4       China  2015          74079.257            5.140
#
#    aqi_pm25_concentration        aqi_pm25_category  indexed_total_consumption  \
# 0               22.703763                     GOOD                   3.718519
# 1              166.870049                UNHEALTHY                   0.870424
# 2               16.508621                     GOOD                   9.503432
# 3               37.279149                     GOOD                  10.357962
# 4              135.612924  UNHEALTHY FOR SENSITIVE                  83.394548
#
#    indexed_happiness_score  indexed_aqi_pm25_concentration
# 0                97.275641                       12.947259
# 1                62.686966                       95.160865
# 2                93.255876                        9.414359
# 3                99.185363                       21.259154
# 4                68.643162                       77.335886

# %%
scaled_df[scaled_df["country"] == "United States"]
# Out:
#            country  year  total_consumption  happiness_score  \
# 23   United States  2015          53417.831           7.1190
# 47   United States  2016          53585.287           7.1040
# 69   United States  2017          53992.588           6.9930
# 92   United States  2018          55937.215           6.8860
# 116  United States  2019          55632.207           6.8920
# 133  United States  2020          51835.538           6.9396
# 144  United States  2021          54639.668           6.9510
#
#      aqi_pm25_concentration aqi_pm25_category  indexed_total_consumption  \
# 23                40.200137              GOOD                  60.134997
# 47                36.144582              GOOD                  60.323510
# 69                38.212483              GOOD                  60.782028
# 92                38.951303              GOOD                  62.971187
# 116               36.073097              GOOD                  62.627825
# 133               37.469787              GOOD                  58.353734
# 144               38.549760              GOOD                  61.510477
#
#      indexed_happiness_score  indexed_aqi_pm25_concentration
# 23                 95.072115                       22.924904
# 47                 94.871795                       20.612145
# 69                 93.389423                       21.791405
# 92                 91.960470                       22.212732
# 116                92.040598                       20.571379
# 133                92.676282                       21.367869
# 144                92.828526                       21.983744

# %% [markdown]
# ## Task 4 & 5

# %% [markdown]
# ## Task 6

# %%
energy_features_for_task_six = ["country", "year", "total_consumption"]
happiness_features_for_task_six = ["country", "year", "happiness_score"]
air_pollution_features_for_task_six = ["country", "year", "aqi_pm25_concentration", "aqi_pm25_category"]
gdp_df_features_for_task_six = ["country", "year", "gdp_per_capita", "gdp"]

task_six_df = pd.merge(energy_df_filtered[energy_features_for_task_six], happiness_df_filtered[happiness_features_for_task_six], on=["country", "year"])
task_six_df = pd.merge(task_six_df, air_quality_df[air_pollution_features_for_task_six], on=["country", "year"])
task_six_df = pd.merge(task_six_df, gdp_df[gdp_df_features_for_task_six], on=["country", "year"])
task_six_df = pd.merge(task_six_df, unemployed_rate_df, on=["country", "year"])
task_six_df = pd.merge(task_six_df, cpi_df, on=["country", "year"])
task_six_df = pd.merge(task_six_df, hdi_df, on=["country", "year"])

task_six_df.head()
# Out:
#       country  year  total_consumption  happiness_score  \
# 0   Australia  2015           5318.155            7.284
# 1  Bangladesh  2015           2788.196            4.694
# 2      Brazil  2015          10456.885            6.983
# 3      Canada  2015          11215.963            7.427
# 4       China  2015          76094.257            5.140
#
#    aqi_pm25_concentration        aqi_pm25_category  gdp_per_capita  \
# 0               22.703763                     GOOD    47858.459864
# 1              166.870049                UNHEALTHY     3497.433948
# 2               16.508621                     GOOD    14718.194722
# 3               37.279149                     GOOD    43938.059091
# 4              135.612924  UNHEALTHY FOR SENSITIVE    13130.370278
#
#             gdp  unemployed_rate       cpi    hdi
# 0  1.140000e+12            6.055  1.508367  0.933
# 1  5.520000e+11            4.382  6.194280  0.604
# 2  3.020000e+12            8.538  9.029901  0.752
# 3  1.570000e+12            6.945  1.125241  0.927
# 4  1.830000e+13            4.650  1.437024  0.741

# %%
task_six_df.to_csv("task_six_scaled.csv", index=False)

# %%
task_six_df = task_six_df.dropna()

# %%
task_six_df
# Out:
#                   country  year  total_consumption  happiness_score  \
# 0               Australia  2015           5318.155            7.284
# 1              Bangladesh  2015           2788.196            4.694
# 2                  Brazil  2015          10456.885            6.983
# 3                  Canada  2015          11215.963            7.427
# 4                   China  2015          76094.257            5.140
# ..                    ...   ...                ...              ...
# 142              Thailand  2021           4894.876            5.985
# 143  United Arab Emirates  2021           4470.781            6.561
# 144         United States  2021          56660.668            6.951
# 145                 Italy  2022           5742.476            6.467
# 146          Saudi Arabia  2022           2022.000            6.523
#
#      aqi_pm25_concentration        aqi_pm25_category  gdp_per_capita  \
# 0                 22.703763                     GOOD    47858.459864
# 1                166.870049                UNHEALTHY     3497.433948
# 2                 16.508621                     GOOD    14718.194722
# 3                 37.279149                     GOOD    43938.059091
# 4                135.612924  UNHEALTHY FOR SENSITIVE    13130.370278
# ..                      ...                      ...             ...
# 142               72.554127                 MODERATE    15362.891611
# 143               95.733460                 MODERATE    77521.457480
# 144               38.549760                     GOOD    56676.956116
# 145                0.000000                     GOOD    36248.164556
# 146               61.863410                 MODERATE    49987.882058
#
#               gdp  unemployed_rate       cpi    hdi
# 0    1.140000e+12            6.055  1.508367  0.933
# 1    5.520000e+11            4.382  6.194280  0.604
# 2    3.020000e+12            8.538  9.029901  0.752
# 3    1.570000e+12            6.945  1.125241  0.927
# 4    1.830000e+13            4.650  1.437024  0.741
# ..            ...              ...       ...    ...
# 142  1.100000e+12            1.215  1.230395  0.797
# 143  7.260000e+11            3.105 -0.013860  0.931
# 144  1.910000e+13            5.349  4.697859  0.921
# 145  2.140000e+12            8.069  8.201290  0.906
# 146  1.820000e+12            5.589  2.474074  0.875
#
# [145 rows x 11 columns]

# %%
from scipy.stats import pearsonr
background = ["total_consumption", "happiness_score"]
sub_factor = ["aqi_pm25_concentration", "gdp_per_capita", "gdp", "unemployed_rate", "cpi", "hdi"]
factor = ["environment", "finance", "living_quality"]

pearsonr_df = pd.DataFrame(columns=["background", "aqi_pm25_concentration", "gdp_per_capita", "gdp", "unemployed_rate", "cpi", "hdi"])

# Iterate over each combination of background and sub_factor
i = 0
for bg in background:
    sub_factor_pearsonr = []
    for sf in sub_factor:
        list1 = task_six_df[bg]
        list2 = task_six_df[sf]
        corr, _ = pearsonr(list1, list2)
        corr = round(corr, 3)
        sub_factor_pearsonr.append(corr)
        print(f"{bg} and {sf} correlation: {corr:.3f}")
    pearsonr_df.loc[i] = [bg] + sub_factor_pearsonr
    i += 1


pearsonr_df.set_index("background", inplace=True)
# Out:
# total_consumption and aqi_pm25_concentration correlation: 0.201
# total_consumption and gdp_per_capita correlation: 0.004
# total_consumption and gdp correlation: 0.979
# total_consumption and unemployed_rate correlation: -0.088
# total_consumption and cpi correlation: -0.070
# total_consumption and hdi correlation: -0.006
# happiness_score and aqi_pm25_concentration correlation: -0.635
# happiness_score and gdp_per_capita correlation: 0.751
# happiness_score and gdp correlation: -0.116
# happiness_score and unemployed_rate correlation: -0.043
# happiness_score and cpi correlation: -0.436
# happiness_score and hdi correlation: 0.797

# %%
tasks_df[tasks_df["year"] == year]
# Out:
#            country  year  total_consumption  energy_consumption_per_capita  \
# 1        Australia  2015           5318.155                       0.000223
# 2       Bangladesh  2015           2788.196                       0.000018
# 3           Brazil  2015          10456.885                       0.000051
# 4           Canada  2015          11215.963                       0.000314
# 5            China  2015          76094.257                       0.000055
# 6          Germany  2015          10139.255                       0.000124
# 8            Spain  2015           5440.409                       0.000117
# 9           France  2015           7938.980                       0.000124
# 10  United Kingdom  2015           6827.641                       0.000105
# 11       Indonesia  2015           5820.061                       0.000022
# 12           India  2015          18440.467                       0.000014
# 13            Iran  2015           7522.797                       0.000092
# 15     South Korea  2015           8683.875                       0.000170
# 16          Mexico  2015           6558.061                       0.000055
# 17     Netherlands  2015           4110.108                       0.000241
# 18     Philippines  2015           2962.758                       0.000029
# 21        Thailand  2015           4829.239                       0.000069
# 22          Turkey  2015           5419.784                       0.000068
# 23   United States  2015          55432.831                       0.000171
# 24         Vietnam  2015           3819.650                       0.000041
#
#     happiness_score  average_pm25_concentration  aqi_pm25_concentration  \
# 1             7.284                    4.086677               22.703763
# 2             4.694                   78.139111              166.870049
# 3             6.983                    2.971552               16.508621
# 4             7.427                    6.710247               37.279149
# 5             5.140                   49.557086              135.612924
# 6             6.750                    5.628137               31.267426
# 8             6.329                    5.815034               32.305747
# 9             6.575                    4.719630               26.220165
# 10            6.867                    6.001604               33.342247
# 11            5.399                   31.486000               92.707757
# 12            4.565                   11.167141               54.851328
# 13            4.686                   29.829000               89.620570
# 15            5.984                   21.761850               74.590519
# 16            7.187                   14.601370               61.249701
# 17            7.378                    7.277762               40.432011
# 18            5.073                   27.333333               84.970849
# 21            6.455                   13.935000               60.008175
# 22            5.332                    5.443633               30.242404
# 23            7.119                    7.236025               40.200137
# 24            5.360                   16.351200               64.509840
#
#           aqi_pm25_category           gdp  gdp_per_capita  unemployed_rate  \
# 1                      GOOD  1.140000e+12    47858.459864            6.055
# 2                 UNHEALTHY  5.520000e+11     3497.433948            4.382
# 3                      GOOD  3.020000e+12    14718.194722            8.538
# 4                      GOOD  1.570000e+12    43938.059091            6.945
# 5   UNHEALTHY FOR SENSITIVE  1.830000e+13    13130.370278            4.650
# 6                      GOOD  3.630000e+12    44228.793134            4.624
# 8                      GOOD  1.490000e+12    32090.391353           22.058
# 9                      GOOD  2.460000e+12    38552.091272           10.354
# 10                     GOOD  2.430000e+12    37256.014501            5.301
# 11                 MODERATE  2.680000e+12    10343.817374            4.514
# 12                 MODERATE  7.390000e+12     5586.353320            7.894
# 13                 MODERATE  1.330000e+12    16260.988026           11.166
# 15                 MODERATE  1.800000e+12    35297.996274            3.546
# 16                 MODERATE  1.920000e+12    15980.038801            4.311
# 17                     GOOD  7.610000e+11    44656.715437            6.873
# 18                 MODERATE  7.630000e+11     7405.512263            3.068
# 21                 MODERATE  1.000000e+12    14225.882662            0.597
# 22                     GOOD  1.730000e+12    21721.067939           10.304
# 23                     GOOD  1.690000e+13    52062.831668            5.280
# 24                 MODERATE  5.560000e+11     6030.931302            1.849
#
#           cpi    hdi
# 1    1.508367  0.933
# 2    6.194280  0.604
# 3    9.029901  0.752
# 4    1.125241  0.927
# 5    1.437024  0.741
# 6    0.514426  0.941
# 8   -0.500366  0.889
# 9    0.037514  0.893
# 10   0.368047  0.923
# 11   6.363121  0.698
# 12   4.906973  0.619
# 13  12.484682  0.782
# 15   0.706332  0.908
# 16   2.720641  0.769
# 17   0.600248  0.932
# 18   0.674193  0.696
# 21  -0.900425  0.789
# 22   7.670854  0.821
# 23   0.118627  0.924
# 24   0.631201  0.697

# %%
from scipy.stats import pearsonr
background = ["total_consumption", "happiness_score"]
sub_factor = ["aqi_pm25_concentration", "gdp_per_capita", "gdp", "unemployed_rate", "cpi", "hdi"]
factor = ["environment", "finance", "living_quality"]

pearsonr_df = pd.DataFrame(columns=["background", "aqi_pm25_concentration", "gdp_per_capita", "gdp", "unemployed_rate", "cpi", "hdi"])

# Iterate over each combination of background and sub_factor
i = 0
for bg in background:
    sub_factor_pearsonr = []
    for sf in sub_factor:
        yearly_correlations = []
        for year in task_six_df["year"].unique():
            list1 = task_six_df[task_six_df["year"] == year][bg]
            list2 = task_six_df[task_six_df["year"] == year][sf]
            if len(list1) > 1 and len(list2) > 1:  # Ensure there are enough data points to calculate correlation
                corr, _ = pearsonr(list1, list2)
                yearly_correlations.append(corr)
        if yearly_correlations:
            avg_corr = round(sum(yearly_correlations) / len(yearly_correlations), 3)
        else:
            avg_corr = None
        sub_factor_pearsonr.append(avg_corr)
        print(f"{bg} and {sf} average correlation: {avg_corr}")
    pearsonr_df.loc[i] = [bg] + sub_factor_pearsonr
    i += 1


pearsonr_df.set_index("background", inplace=True)
# Out:
# total_consumption and aqi_pm25_concentration average correlation: 0.042
# total_consumption and gdp_per_capita average correlation: -0.093
# total_consumption and gdp average correlation: 0.984
# total_consumption and unemployed_rate average correlation: 0.048
# total_consumption and cpi average correlation: 0.091
# total_consumption and hdi average correlation: 0.14
# happiness_score and aqi_pm25_concentration average correlation: -0.374
# happiness_score and gdp_per_capita average correlation: 0.792
# happiness_score and gdp average correlation: -0.187
# happiness_score and unemployed_rate average correlation: -0.147
# happiness_score and cpi average correlation: -0.515
# happiness_score and hdi average correlation: 0.594

# %%
from scipy.stats import pearsonr
background = ["total_consumption","energy_consumption_per_capita", "happiness_score"]
sub_factor = ["aqi_pm25_concentration", "gdp_per_capita", "gdp", "unemployed_rate", "cpi", "hdi"]
factor = ["environment", "finance", "living_quality"]

pearsonr_df = pd.DataFrame(columns=["background", "aqi_pm25_concentration", "gdp_per_capita", "gdp", "unemployed_rate", "cpi", "hdi"])

# Iterate over each combination of background and sub_factor
i = 0
for bg in background:
    sub_factor_pearsonr = []
    for sf in sub_factor:
        yearly_correlations = []
        for year in tasks_df["year"].unique():
            list1 = tasks_df[tasks_df["year"] == year][bg]
            list2 = tasks_df[tasks_df["year"] == year][sf]
            if len(list1) > 1 and len(list2) > 1:  # Ensure there are enough data points to calculate correlation
                corr, _ = pearsonr(list1, list2)
                yearly_correlations.append(corr)
        if yearly_correlations:
            avg_corr = round(sum(yearly_correlations) / len(yearly_correlations), 3)
        else:
            avg_corr = None
        sub_factor_pearsonr.append(avg_corr)
        print(f"{bg} and {sf} average correlation: {avg_corr}")
    pearsonr_df.loc[i] = [bg] + sub_factor_pearsonr
    i += 1


pearsonr_df.set_index("background", inplace=True)
# Out:
# total_consumption and aqi_pm25_concentration average correlation: 0.163
# total_consumption and gdp_per_capita average correlation: 0.057
# total_consumption and gdp average correlation: 0.983
# total_consumption and unemployed_rate average correlation: -0.102
# total_consumption and cpi average correlation: 0.016
# total_consumption and hdi average correlation: 0.015
# energy_consumption_per_capita and aqi_pm25_concentration average correlation: -0.346
# energy_consumption_per_capita and gdp_per_capita average correlation: 0.867
# energy_consumption_per_capita and gdp average correlation: -0.114
# energy_consumption_per_capita and unemployed_rate average correlation: -0.059
# energy_consumption_per_capita and cpi average correlation: -0.382
# energy_consumption_per_capita and hdi average correlation: 0.685
# happiness_score and aqi_pm25_concentration average correlation: -0.703
# happiness_score and gdp_per_capita average correlation: 0.782
# happiness_score and gdp average correlation: -0.067
# happiness_score and unemployed_rate average correlation: 0.018
# happiness_score and cpi average correlation: -0.303
# happiness_score and hdi average correlation: 0.821

# %%
# old version
pearsonr_df
# Out:
#                    aqi_pm25_concentration  gdp_per_capita    gdp  \
# background
# total_consumption                   0.201           0.004  0.979
# happiness_score                    -0.635           0.751 -0.116
#
#                    unemployed_rate    cpi  human_development_index
# background
# total_consumption           -0.088 -0.070                   -0.006
# happiness_score             -0.043 -0.436                    0.797

# %%
pearsonr_df
# Out:
#                                aqi_pm25_concentration  gdp_per_capita    gdp  \
# background
# total_consumption                               0.163           0.057  0.983
# energy_consumption_per_capita                  -0.346           0.867 -0.114
# happiness_score                                -0.703           0.782 -0.067
#
#                                unemployed_rate    cpi    hdi
# background
# total_consumption                       -0.102  0.016  0.015
# energy_consumption_per_capita           -0.059 -0.382  0.685
# happiness_score                          0.018 -0.303  0.821

# %%
from sklearn.preprocessing import StandardScaler
environment = ["aqi_pm25_concentration"]
living_quality = ["hdi"]


for bg in background:
    task_six_df_cp = task_six_df.copy()
    if bg == "total_consumption":
        finance = ["gdp", "cpi", "unemployed_rate"]
    else:
        finance = ["gdp_per_capita", "cpi", "unemployed_rate"]
    scaler = StandardScaler()
    tasks_df[finance] = scaler.fit_transform(tasks_df[finance])
    tasks_df['finance'] = tasks_df[finance].mean(axis=1)
    corr, _ = pearsonr(tasks_df['finance'], tasks_df[bg])
    pearsonr_df.loc[bg, "finance"] = round(corr, 3)
    
pearsonr_df['environment'] = pearsonr_df["aqi_pm25_concentration"]
pearsonr_df['living_quality'] = pearsonr_df["hdi"]

# %%
pearsonr_df
# Out:
#                                aqi_pm25_concentration  gdp_per_capita    gdp  \
# background
# total_consumption                               0.163           0.057  0.983
# energy_consumption_per_capita                  -0.346           0.867 -0.114
# happiness_score                                -0.703           0.782 -0.067
#
#                                unemployed_rate    cpi    hdi  finance  \
# background
# total_consumption                       -0.102  0.016  0.015    0.458
# energy_consumption_per_capita           -0.059 -0.382  0.685    0.263
# happiness_score                          0.018 -0.303  0.821    0.223
#
#                                environment  living_quality
# background
# total_consumption                    0.163           0.015
# energy_consumption_per_capita       -0.346           0.685
# happiness_score                     -0.703           0.821

# %%
pearsonr_df.to_csv("pearsonr_df.csv", index=False)
